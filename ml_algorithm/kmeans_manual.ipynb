# %%
import numpy as np

# Here we want to build the Kmeans algorithm from scratch using numpy
class KMeans:
    # Initialize the number of clusters and the number of iterations
    def __init__(self, n_clusters=3, max_iterations=100):
        self.n_clusters = n_clusters
        self.max_iterations = max_iterations
        self.centroids = None

    # Fit the model to the data
    def fit(self, X):
        # 1. Create a random set of centroids
        # 2. Assign each data point to each of the centroids
        # 3. Update the centroids by calculating the mean of the data points related to each centroid
        # 4. Repeat the process until the centroids do not change or until the number of iterations is reached

        random_
